# %%
import nltk
import pandas as pd

from nltk.corpus import brown
from nltk.stem import PorterStemmer, WordNetLemmatizer

nltk.download('brown')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package brown to /home/parth/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/parth/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/parth/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
# Get alphabetic words from the Brown Corpus
words = [word.lower() for word in brown.words() if word.isalpha()]

# Add the words specifically required in the assignment
required_words = ['playing', 'studies', 'running', 'better', 'cars']

# Select 30 words and include the required examples
selected_words = words[:30] + required_words

print("Number of words:", len(selected_words))
print(selected_words)
# Out:
# Number of words: 35
# ['the', 'fulton', 'county', 'grand', 'jury', 'said', 'friday', 'an', 'investigation', 'of', 'recent', 'primary', 'election', 'produced', 'no', 'evidence', 'that', 'any', 'irregularities', 'took', 'place', 'the', 'jury', 'further', 'said', 'in', 'presentments', 'that', 'the', 'city', 'playing', 'studies', 'running', 'better', 'cars']

# %%
# Create stemmer and lemmatizer
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# Apply stemming and lemmatization
stemmed_words = [stemmer.stem(word) for word in selected_words]
lemmatized_words = [lemmatizer.lemmatize(word) for word in selected_words]

# Create comparison DataFrame
df = pd.DataFrame({
    'Original Word': selected_words,
    'Stemmed': stemmed_words,
    'Lemmatized': lemmatized_words
})

df
# Out:
#      Original Word    Stemmed     Lemmatized
# 0              the        the            the
# 1           fulton     fulton         fulton
# 2           county     counti         county
# 3            grand      grand          grand
# 4             jury       juri           jury
# 5             said       said           said
# 6           friday     friday         friday
# 7               an         an             an
# 8    investigation   investig  investigation
# 9               of         of             of
# 10          recent     recent         recent
# 11         primary    primari        primary
# 12        election      elect       election
# 13        produced     produc       produced
# 14              no         no             no
# 15        evidence       evid       evidence
# 16            that       that           that
# 17             any        ani            any
# 18  irregularities  irregular   irregularity
# 19            took       took           took
# ...

# %%
# Display the required examples
df[df['Original Word'].isin(
    ['playing', 'studies', 'running', 'better', 'cars']
)]
# Out:
#    Original Word Stemmed Lemmatized
# 30       playing    play    playing
# 31       studies   studi      study
# 32       running     run    running
# 33        better  better     better
# 34          cars     car        car
